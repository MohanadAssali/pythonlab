# %%
import yfinance as yf
import pandas as pd
from pandas_datareader import data as pdr
import datetime as dt
import numpy as np

# %%
enddate = dt.datetime.now()
startdate = enddate - dt.timedelta(days = 365*5)
enddate, startdate
stocks = ['AVGO']

# %%
df['Close'].plot(figsize=(12, 6))
plt.title("Share Price Over Time")
plt.ylabel("Price ($)")
plt.show()

# %%
import mplfinance as mpf

# %%
avgo_data = df.xs('AVGO', axis=1, level=1).tail(100)
mpf.plot(avgo_data, type='candle', style='charles',title="AVGO Zoomed (Last 100 Days)",ylabel="Price ($)", figsize=(15, 8))

# %%
avgo_data = df.xs('AVGO', axis=1, level=1).tail(100)
mpf.plot(avgo_data, type='candle', style='charles',title="AVGO Zoomed (Last 100 Days)",ylabel="Price ($)",ema=50, 
 figsize=(15, 8))

# %%
avgo_data = df.xs('AVGO', axis=1, level=1).tail(100)
mpf.plot(avgo_data, type='candle', style='charles',title="AVGO Zoomed (Last 100 Days)",ylabel="Price ($)",ema=50, 
volume=True, figsize=(15, 8))
