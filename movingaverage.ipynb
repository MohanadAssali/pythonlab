# %%
import yfinance as yf
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
"""Adjusted Close"""
df = yf.download(stocks, start=startdate, end=enddate, auto_adjust=False) #-------- Force yfinance to only show Adj Close
adj_close_prices = df['Adj Close']
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
ma50 = adj_close_prices.rolling(window=50).mean()
ma100 = adj_close_prices.rolling(window=100).mean()
ma200 = adj_close_prices.rolling(window=200).mean()
plt.figure(figsize=(12, 6))
plt.plot(adj_close_prices['AVGO'], label='AVGO Price', color='gray', alpha=0.3)
plt.plot(ma50['AVGO'], label='50 MA', color='blue', linewidth=1)
plt.plot(ma100['AVGO'], label='100 MA', color='orange', linewidth=1)
plt.plot(ma200['AVGO'], label='200 MA', color='red', linewidth=1.5)
plt.title("Broadcom (AVGO) Price with 50, 100, & 200 Day MAs")
plt.xlabel("Date")
plt.ylabel("Price ($)")
plt.legend()
plt.show()
