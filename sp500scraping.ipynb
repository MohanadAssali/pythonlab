# %%
import pandas as pd
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
headers = {'User-Agent': 'Mozilla/5.0'}
df = pd.read_html(url, storage_options=headers)[0]


tickers = df['Symbol'].str.replace('.', '-', regex=False).tolist()
print(f"Success! Found {len(tickers)} tickers.")
# Out:
# Success! Found 503 tickers.

# %%
 print(tickers[:50])
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'AON', 'APA', 'APO', 'AAPL', 'AMAT', 'APP', 'APTV', 'ACGL', 'ADM', 'ARES', 'ANET', 'AJG', 'AIZ', 'T', 'ATO']

# %%
sector_counts = df['GICS Sector'].value_counts()
print(sector_counts)
# Out:
# GICS Sector
# Industrials               80
# Financials                76
# Information Technology    70
# Health Care               60
# Consumer Discretionary    48
# Consumer Staples          36
# Utilities                 31
# Real Estate               31
# Materials                 26
# Communication Services    23
# Energy                    22
# Name: count, dtype: int64

# %%
tech_stocks = df[df['GICS Sector'] == 'Information Technology'][['Symbol', 'Security']]
print(tech_stocks.head(10))
# Out:
#    Symbol                Security
# 4     ACN               Accenture
# 5    ADBE              Adobe Inc.
# 6     AMD  Advanced Micro Devices
# 12   AKAM     Akamai Technologies
# 33    APH                Amphenol
# 34    ADI          Analog Devices
# 38   AAPL              Apple Inc.
# 39   AMAT       Applied Materials
# 40    APP                AppLovin
# 45   ANET         Arista Networks

# %%
print(df['Headquarters Location'].head(20))
# Out:
# 0                     Saint Paul, Minnesota
# 1                      Milwaukee, Wisconsin
# 2                   North Chicago, Illinois
# 3                   North Chicago, Illinois
# 4                           Dublin, Ireland
# 5                      San Jose, California
# 6                   Santa Clara, California
# 7                       Arlington, Virginia
# 8                         Columbus, Georgia
# 9                   Santa Clara, California
# 10    Upper Macungie Township, Pennsylvania
# 11                San Francisco, California
# 12                 Cambridge, Massachusetts
# 13                Charlotte, North Carolina
# 14                     Pasadena, California
# 15                           Tempe, Arizona
# 16                          Dublin, Ireland
# 17                       Madison, Wisconsin
# 18                     Northbrook, Illinois
# 19                Mountain View, California
# Name: Headquarters Location, dtype: object

# %%
result = df[df['Symbol'] == 'AVGO']
print(result)
# Out:
#    Symbol  Security             GICS Sector GICS Sub-Industry  \
# 73   AVGO  Broadcom  Information Technology    Semiconductors
#
#     Headquarters Location  Date added      CIK Founded
# 73  Palo Alto, California  2014-05-08  1730168    1961

# %%
print(df.describe(include='all'))
# Out:
#        Symbol Security  GICS Sector      GICS Sub-Industry  \
# count     503      503          503                    503
# unique    503      503           11                    127
# top       MMM       3M  Industrials  Health Care Equipment
# freq        1        1           80                     17
# mean      NaN      NaN          NaN                    NaN
# std       NaN      NaN          NaN                    NaN
# min       NaN      NaN          NaN                    NaN
# 25%       NaN      NaN          NaN                    NaN
# 50%       NaN      NaN          NaN                    NaN
# 75%       NaN      NaN          NaN                    NaN
# max       NaN      NaN          NaN                    NaN
#
#           Headquarters Location  Date added           CIK Founded
# count                       503         503  5.030000e+02     503
# unique                      248         372           NaN     195
# ...

# %%
watchlist = df[df['Symbol'].isin(['AAPL', 'TSLA', 'NVDA'])]
print(watchlist)
# Out:
#     Symbol     Security             GICS Sector  \
# 38    AAPL   Apple Inc.  Information Technology
# 344   NVDA       Nvidia  Information Technology
# 440   TSLA  Tesla, Inc.  Consumer Discretionary
#
#                               GICS Sub-Industry    Headquarters Location  \
# 38   Technology Hardware, Storage & Peripherals    Cupertino, California
# 344                              Semiconductors  Santa Clara, California
# 440                    Automobile Manufacturers            Austin, Texas
#
#      Date added      CIK Founded
# 38   1982-11-30   320193    1977
# 344  2001-11-30  1045810    1993
# 440  2020-12-21  1318605    2003

# %%
df.to_csv('sp500list.csv', index=False)
